# %% [markdown]
# <a href="https://colab.research.google.com/github/notorious0789/Study-of-Categorical-Data-Analysis/blob/main/Practical_11_Study_of_Categorical_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment - 11
# ## Title : Study of Categorical Data Analysis
# ### Name : Apoorba Chatterjee
# ### PRN : 25070123020

# %%
import pandas as pd
data = {

'Order_ID':['01','02','03','04','05','06','07','08','09','010'],

'Category':['Electronics','Clothing','Electronics','Grocery','Clothing',
            'Electronics','Grocery','Clothing','Electronics','Grocery'],

'Payment_Method':['UPI','CARD','UPI','CASH','CARD',
                  'UPI','CASH','CARD','UPI','CASH'],

'Delivery_Status': ['Express','Standard','Express','Standard','Express',
                    'Standard','Express','Standard','Express','Standard'],

'Customer_Type':['Regular','New','Regular','New','Regular',
                 'New','Regular','New','Regular','New']

}

df=pd.DataFrame(data)
print(df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Status Customer_Type
# 0       01  Electronics            UPI         Express       Regular
# 1       02     Clothing           CARD        Standard           New
# 2       03  Electronics            UPI         Express       Regular
# 3       04      Grocery           CASH        Standard           New
# 4       05     Clothing           CARD         Express       Regular
# 5       06  Electronics            UPI        Standard           New
# 6       07      Grocery           CASH         Express       Regular
# 7       08     Clothing           CARD        Standard           New
# 8       09  Electronics            UPI         Express       Regular
# 9      010      Grocery           CASH        Standard           New

# %%
#1. Frequency Count
#Count how many orders in each category

print(df['Category'].value_counts())
# Out:
# Category
# Electronics    4
# Clothing       3
# Grocery        3
# Name: count, dtype: int64

# %%
print(df['Payment_Method'].value_counts())
# Out:
# Payment_Method
# UPI     4
# CARD    3
# CASH    3
# Name: count, dtype: int64

# %%
#2. Unique Values

#Display all unique categories

print(df['Category'].unique())
# Out:
# ['Electronics' 'Clothing' 'Grocery']

# %%
#3. Number of Unique Values
print(df['Category'].nunique())
# Out:
# 3

# %%
#4. Frequency of Payment Methods
print(df['Payment_Method'].value_counts())
# Out:
# Payment_Method
# UPI     4
# CARD    3
# CASH    3
# Name: count, dtype: int64

# %%
#5. Cross Tabulation

#Category vs Payment Method

print(pd.crosstab(df['Category'],df['Payment_Method']))
# Out:
# Payment_Method  CARD  CASH  UPI
# Category
# Clothing           3     0    0
# Electronics        0     0    4
# Grocery            0     3    0

# %%
#6. Cross Tabulation (Delivery vs Customer Type)

print(pd.crosstab(df['Delivery_Status'],df['Customer_Type']))
# Out:
# Customer_Type    New  Regular
# Delivery_Status
# Express            0        5
# Standard           5        0

# %%
#7. Percentage Distribution
print(df['Category'].value_counts(normalize=True)*100)
# Out:
# Category
# Electronics    40.0
# Clothing       30.0
# Grocery        30.0
# Name: proportion, dtype: float64

# %%
#8. Filtering Data
#Example: Orders from Electronics category

electronics_orders=df[df['Category']=='Electronics']
print(electronics_orders)
# Out:
#   Order_ID     Category Payment_Method Delivery_Status Customer_Type
# 0       01  Electronics            UPI         Express       Regular
# 2       03  Electronics            UPI         Express       Regular
# 5       06  Electronics            UPI        Standard           New
# 8       09  Electronics            UPI         Express       Regular

# %%
#9. Grouping
#Orders by category and payment method

print(df.groupby(['Category','Payment_Method']).size())
# Out:
# Category     Payment_Method
# Clothing     CARD              3
# Electronics  UPI               4
# Grocery      CASH              3
# dtype: int64

# %%
#10. Sorting Data
sorted_df = df.sort_values(by='Category')
print(sorted_df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Status Customer_Type
# 1       02     Clothing           CARD        Standard           New
# 4       05     Clothing           CARD         Express       Regular
# 7       08     Clothing           CARD        Standard           New
# 0       01  Electronics            UPI         Express       Regular
# 2       03  Electronics            UPI         Express       Regular
# 5       06  Electronics            UPI        Standard           New
# 8       09  Electronics            UPI         Express       Regular
# 3       04      Grocery           CASH        Standard           New
# 6       07      Grocery           CASH         Express       Regular
# 9      010      Grocery           CASH        Standard           New

# %%
#Second Dataset
import pandas as pd
df=pd.read_csv('/content/Expt11.csv')
print(df.head())
# Out:
#   Student  Gender Department Grade
# 0      S1    Male        CSE     A
# 1      S2  Female         IT     B
# 2      S3  Female        CSE     A
# 3      S4    Male        ECE     C
# 4      S5    Male         IT     B

# %%
#1. PS- Count Students in Each Grade
#Find how mnay students obtained each grade

print("Grade Frequency")
print(df['Grade'].value_counts())
# Out:
# Grade Frequency
# Grade
# B    24
# A    22
# C    14
# Name: count, dtype: int64

# %%
#2. PS - Percentage Distribution

print("Grade Percentage")
print(df['Grade'].value_counts(normalize=True)*100)
# Out:
# Grade Percentage
# Grade
# B    40.000000
# A    36.666667
# C    23.333333
# Name: proportion, dtype: float64

# %%
#3. PS - Number of Students in Each Department

print("Department Count")
print(df['Department'].value_counts())
# Out:
# Department Count
# Department
# CSE           20
# IT            18
# ECE           11
# Mechanical    11
# Name: count, dtype: int64

# %%
#4. PS - Gender Distribution

print("Gender Count")
print(df['Gender'].value_counts())
# Out:
# Gender Count
# Gender
# Male      30
# Female    30
# Name: count, dtype: int64

# %%
#5. PS - Gender vc Grade Analysis

print(pd.crosstab(df['Gender'],df['Grade']))
# Out:
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9

# %%
#6. PS - Department vs Gender

print(pd.crosstab(df['Department'],df['Gender']))
# Out:
# Gender      Female  Male
# Department
# CSE             12     8
# ECE              5     6
# IT               9     9
# Mechanical       4     7

# %%
#7. PS - Department vs Grade Percentage

# %%
#8. PS - Grouping Data

print(df.groupby('Department')['Grade'].value_counts())
# Out:
# Department  Grade
# CSE         A        13
#             B         4
#             C         3
# ECE         B         5
#             C         4
#             A         2
# IT          B         8
#             A         7
#             C         3
# Mechanical  B         7
#             C         4
# Name: count, dtype: int64
